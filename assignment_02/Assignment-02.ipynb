# %% [markdown]
# # Assignment 02
# **Author**: Crista Barnes
#
# **Date**: 2/5/2021

# %% [markdown]
# ## Create a list of 10 integers with user input

# %%
#Create a blank list
int_list = []
#Create a for loop to iterate through integer user request
for i in range(1,11):
    while True:
        try:
            integer=int(input("input an integer:"))
            print(f"You have entered #{i}", integer)
            int_list.append(integer)
        except ValueError: 
            print("Only integers are allowed")
            continue
        break
print("Overall, you have entered:", int_list)
# Out:
# You have entered #1 -55
# You have entered #2 5
# You have entered #3 76
# You have entered #4 100
# You have entered #5 -6
# You have entered #6 3
# You have entered #7 13
# You have entered #8 1
# You have entered #9 -100
# You have entered #10 16
# Overall, you have entered: [-55, 5, 76, 100, -6, 3, 13, 1, -100, 16]

# %% [markdown]
# ## Calculate Maximum

# %%
# Set the first number in the list to the maximum
maxnum=int_list[0]
# Create a for loop to test each number in the list against the reigning maximum
for i in range(0, len(int_list)):
    # If the tested number succeds, set it as the new maximum
    if int_list[i]>maxnum:
        maxnum=int_list[i]
print("The Maximum is:", maxnum)
# Out:
# The Maximum is: 100

# %% [markdown]
# ## Calculate Minimum

# %%
# Set the first number in the list to the minimum
minnum=int_list[0]
# Create a for loop to test each number in the list against the reigning minimum
for i in range(0, len(int_list)):
    # If the tested number succeds, set it as the new minimum
    if int_list[i]<minnum:
        minnum=int_list[i]
print("The Minimum is:", minnum)
# Out:
# The Minimum is: -100

# %% [markdown]
# ## Calculate Range

# %%
# Range = List Max - List Min
rng=maxnum-minnum
print("The Range is:", rng)
# Out:
# The Range is: 200

# %% [markdown]
# ## Calculate Mean

# %%
# Mean = Sum of list / length of list
mean=sum(int_list)/len(int_list)
print("The Mean is:", mean)
# Out:
# The Mean is: 5.3

# %% [markdown]
# ## Calculate Variance

# %%
# Variance = The average of the squared difference from the mean
# Create a new list for the squared differences
dif_sqr_list=[] 
# Calculate the difference from the mean of each value, and square it  
for i in range(0, len(int_list)):
    difference=mean-int_list[i]
    dif_sqr=difference ** 2
    dif_sqr_list.append(dif_sqr)
# Average out the list of squared difference
var=sum(dif_sqr_list)/len(dif_sqr_list)
print("The Varience is:", round(var, 2))
# Out:
# The Varience is: 2901.61

# %% [markdown]
# ## Calculate Standard Deviation

# %%
# Standard Deviation = Square Root of Variance
StrDev=var ** (1/2)
print("The Standard Deviation is:", round(StrDev, 2))
# Out:
# The Standard Deviation is: 53.87

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=eb0a1b1e-7717-4570-b08b-c403cebb0472' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
